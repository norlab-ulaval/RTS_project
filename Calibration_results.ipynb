# %%
# Calibration file

# Notebook used to compute the inter-prism and inter-GPS distance after an experiment
# This notebook can also compute the inter-prism distance for marmotte and gives the prism positions
# into the lidar frame.
# Experiments are sorted by dates
# Just the calibration file is needed

# %%
import sys
#!{sys.executable} -m pip install seaborn
#!{sys.executable} -m pip install pycryptodome
#!{sys.executable} -m pip install pycryptodomex
#!{sys.executable} -m pip install gnupg
import numpy as np
import importlib
import matplotlib.pyplot as plt
import scripts.theodolite_function as tfu
tfu = importlib.reload(tfu)
from scipy.interpolate import splprep, splev
from scipy import interpolate
import seaborn as sns

from matplotlib.colors import BoundaryNorm
from matplotlib.ticker import MaxNLocator
from scipy.spatial.transform import Rotation as R
import scripts.theodolite_utils as ttfu
# Out:
# Failed to load Python extension for LZ4 support. LZ4 compression will not be available.
# Python older than 3.7 detected.

# %%
# 1 11 21
ttfu = importlib.reload(ttfu)
file_name = "./data/calibration/lab_calib/20211101_calibration_warthog.csv"
file_name_output = "./data/calibration/distance_calib/20210111_calibration_distance.csv"
P1, P2, P3, G1, G2, G3= ttfu.read_calibration_gps_prism(file_name, file_name_output)
# Out:
# Distance inter-prism:  1.0398341231585624 0.818424700118086 0.8806156053859284
# Distance inter-GPS:  0.8347716172534116 0.7808823763420246 0.5150290652590782
# Conversion done !

# %%
# 26 11 21
ttfu = importlib.reload(ttfu)
file_name = "./data/calibration/lab_calib/20211126_calibration_warthog.csv"
file_name_output = "./data/calibration/distance_calib/20211126_calibration_distance.csv"
P1, P2, P3, G1, G2, G3= ttfu.read_calibration_gps_prism(file_name, file_name_output)
# Out:
# Distance inter-prism:  1.03688797895733 0.822536135483593 0.8783765747673403
# Distance inter-GPS:  0.782263201322596 0.8376474987979826 0.5157164402181366
# Conversion done !

# %%
# 31 01 22
ttfu = importlib.reload(ttfu)
file_name = "./data/calibration/lab_calib/20220131_calibration_warthog.csv"
file_name_output = "./data/calibration/distance_calib/20220131_calibration_distance.csv"
P1, P2, P3, G1, G2, G3, L = ttfu.read_calibration_gps_prism_lidar(file_name, file_name_output)
# Out:
# Distance inter-prism:  1.038854051807371 0.8202157646292075 0.879788333022114
# Distance inter-GPS:  0.7827334106178546 0.8409235045442768 0.515682132155924
# Conversion done !

# %%
# 03 02 22
ttfu = importlib.reload(ttfu)
file_name = "./data/calibration/lab_calib/20220209_calibration_warthog.csv"
file_name_output = "./data/calibration/distance_calib/20220209_calibration_distance.csv"
P1, P2, P3, G1, G2, G3, L = ttfu.read_calibration_gps_prism_lidar(file_name, file_name_output)
# Out:
# Distance inter-prism:  1.0403741344089559 0.8239475424257701 0.8766711748547112
# Distance inter-GPS:  0.7814061923717721 0.8345258764118164 0.515961382866514
# Conversion done !

# %%
# 17 02 22
ttfu = importlib.reload(ttfu)
file_name = "./data/calibration/lab_calib/20220217_calibration_warthog.csv"
file_name_output = "./data/calibration/distance_calib/20220217_calibration_distance.csv"
P1, P2, P3, G1, G2, G3, L = ttfu.read_calibration_gps_prism_lidar(file_name, file_name_output)
# Out:
# Distance inter-prism:  0.8882613537922258 0.8262903370535766 1.0377436460567973
# Distance inter-GPS:  0.780733617998497 0.8366106177748998 0.5178917909150109
# Conversion done !

# %%
# 07 03 22
ttfu = importlib.reload(ttfu)
file_name = "./data/calibration/lab_calib/20220307_calibration_warthog.csv"
file_name_output = "./data/calibration/distance_calib/20220307_calibration_distance.csv"
P1, P2, P3, G1, G2, G3, L = ttfu.read_calibration_gps_prism_lidar(file_name, file_name_output)
print(P1)
print(P2)
print(P3)
print(G1)
print(G2)
print(G3)
# Out:
# Distance inter-prism:  0.8832836583456264 0.8247449387008166 1.039409793600046
# Distance inter-GPS:  0.7781099344563802 0.8431026980109139 0.5157221841320069
# Conversion done !
# [ 2.79360657 -0.75496448 -0.08255881  1.        ]
# [ 3.60741011 -0.55620035 -0.36257069  1.        ]
# [ 2.73073210e+00  3.70690961e-04 -4.07704620e-01  1.00000000e+00]
# [ 2.54427429 -0.50644668 -0.72279256  1.        ]
# [ 3.29508752 -0.68536252 -0.62418381  1.        ]
# [ 3.30769341 -0.17035809 -0.60008203  1.        ]

# %%
# 12 03 22
ttfu = importlib.reload(ttfu)
file_name = "./data/calibration/lab_calib/20220312_calibration_warthog.csv"
file_name_output = "./data/calibration/distance_calib/20220312_calibration_distance.csv"
P1, P2, P3, G1, G2, G3, L = ttfu.read_calibration_gps_prism_lidar(file_name, file_name_output)
# Out:
# Distance inter-prism:  0.8860734460339026 0.8303896290142598 1.0393117663247973
# Distance inter-GPS:  0.7829424296161074 0.8415176433032493 0.5161917038941966
# Conversion done !

# %%
# 14 03 22
ttfu = importlib.reload(ttfu)
file_name = "./data/calibration/lab_calib/20220314_calibration_warthog.csv"
file_name_output = "./data/calibration/distance_calib/20220314_calibration_distance.csv"
P1, P2, P3, G1, G2, G3, L = ttfu.read_calibration_gps_prism_lidar(file_name, file_name_output)
print(P1)
print(P2)
print(P3)
print(G1)
print(G2)
print(G3)
# Out:
# Distance inter-prism:  0.8873171656784946 0.8272212117473343 1.0379270641796363
# Distance inter-GPS:  0.7829081036179948 0.8424633975958637 0.5165807364575292
# Conversion done !
# [ 3.16757534 -0.42103498 -0.12806262  1.        ]
# [ 3.89296346e+00  1.96285659e-03 -4.14797074e-01  1.00000000e+00]
# [ 2.89566976  0.28583646 -0.46077129  1.        ]
# [ 2.85818819 -0.25079912 -0.77501231  1.        ]
# [ 3.63328716 -0.20827459 -0.67323631  1.        ]
# [ 3.49290871  0.28817526 -0.64702379  1.        ]

# %%
# 31 03 22
ttfu = importlib.reload(ttfu)
file_name = "./data/calibration/lab_calib/20220331_calibration_warthog.csv"
file_name_output = "./data/calibration/distance_calib/20220331_calibration_distance.csv"
P1, P2, P3, G1, G2, G3, L = ttfu.read_calibration_gps_prism_lidar(file_name, file_name_output)
# Out:
# Distance inter-prism:  0.8864675130714769 0.8240907534046003 1.0386580905077105
# Distance inter-GPS:  0.7840545151932103 0.8371156718750876 0.5167633057807889
# Conversion done !

# %%
# 27 04 22
ttfu = importlib.reload(ttfu)
file_name = "./data/calibration/lab_calib/20220427_calibration_warthog.csv"
file_name_output = "./data/calibration/distance_calib/20220427_calibration_distance.csv"
P1, P2, P3, G1, G2, G3, L = ttfu.read_calibration_gps_prism_lidar(file_name, file_name_output)
print(P1)
print(P2)
print(P3)
print(G1)
print(G2)
print(G3)
# Out:
# Distance inter-prism:  0.8856608085851714 0.8264452483880412 1.0384219210289538
# Distance inter-GPS:  0.7809547832390561 0.8259590286006459 0.5191274645630007
# Conversion done !
# [ 4.11096954 -0.35233403 -0.08898985  1.        ]
# [ 4.84303243  0.01230338 -0.42887005  1.        ]
# [ 3.86027581  0.34699179 -0.45107796  1.        ]
# [ 3.7794931  -0.2032015  -0.73155045  1.        ]
# [ 4.55792589 -0.19725434 -0.6691213   1.        ]
# [ 4.42670336  0.30493042 -0.65993241  1.        ]

# %%
# 27 04 22 soir
ttfu = importlib.reload(ttfu)
file_name = "./data/calibration/lab_calib/20220427_soir_calibration_warthog.csv"
file_name_output = "./data/calibration/distance_calib/20220427_soir_calibration_distance.csv"
P1, P2, P3, G1, G2, G3, L = ttfu.read_calibration_gps_prism_lidar(file_name, file_name_output)
# Out:
# Distance inter-prism:  0.8868846942534616 0.829169129877633 1.0387571594276301
# Distance inter-GPS:  0.7837749633840095 0.8323125081688734 0.5187055120945835
# Conversion done !

# %%
# 05 05 22
ttfu = importlib.reload(ttfu)
file_name = "./data/calibration/lab_calib/20220505_calibration_marmotte.csv"
file_name_output = "./data/calibration/distance_calib/20220505_calibration_distance_marmotte.csv"
V1, V2, V3, V4, G1, G2, A1, A2, A3, p1, p2, p3 = ttfu.read_calibration_prism_lidar_marmotte(file_name, file_name_output)
# Out:
# [[-0.93567512  0.32769312 -0.13087895  2.07493247]
#  [-0.33633689 -0.94041765  0.04992143  0.85945263]
#  [-0.10672197  0.09072965  0.99014067  1.09340118]
#  [ 0.          0.          0.          1.        ]]
# [-0.39266833 -0.06981451  0.37458417  1.        ]
# [-0.64805967 -0.1117802   0.0936504   1.        ]
# [-0.64132562  0.14408138  0.07735248  1.        ]
# Distance inter-prism:  0.3819811991689936 0.4426382054042266 0.2564685508415531
# Conversion done !

# %%
# 13 05 22
ttfu = importlib.reload(ttfu)
file_name = "./data/calibration/lab_calib/20220513_calibration_warthog.csv"
file_name_output = "./data/calibration/distance_calib/20220513_calibration_distance.csv"
P1, P2, P3, G1, G2, G3, L = ttfu.read_calibration_gps_prism_lidar(file_name, file_name_output)
# Out:
# Distance inter-prism:  0.8113569618671205 0.8695313906832193 1.0383292631343506
# Distance inter-GPS:  0.7800801192552722 0.8396027021467387 0.5157656903777014
# Conversion done !

# %%
# 05 05 22
ttfu = importlib.reload(ttfu)
file_name = "./data/calibration/lab_calib/20220523_calibration_marmotte.csv"
file_name_output = "./data/calibration/distance_calib/20220523_calibration_distance_marmotte.csv"
V1, V2, V3, V4, G1, G2, A1, A2, A3, p1, p2, p3 = ttfu.read_calibration_prism_lidar_marmotte(file_name, file_name_output)
# Out:
# [[-0.84707759  0.51536875 -0.12982532  2.0814866 ]
#  [-0.52885229 -0.84158272  0.10978971  1.63945263]
#  [-0.05267656  0.16165882  0.9854398   1.25969219]
#  [ 0.          0.          0.          1.        ]]
# [-0.38468404 -0.03935277  0.38121922  1.        ]
# [-0.64279424 -0.09226772  0.10023607  1.        ]
# [-0.63500022  0.16525106  0.07778268  1.        ]
# Distance inter-prism:  0.3851913749758221 0.4433899497583272 0.25861327466684897
# Conversion done !

# %%
# 25 05 22
ttfu = importlib.reload(ttfu)
file_name = "./data/calibration/lab_calib/20220525_calibration_warthog.csv"
file_name_output = "./data/calibration/distance_calib/20220525_calibration_distance.csv"
P1, P2, P3, G1, G2, G3, L = ttfu.read_calibration_gps_prism_lidar(file_name, file_name_output)
# Out:
# Distance inter-prism:  0.9095421527752512 0.7356677023921305 1.0283049452358466
# Distance inter-GPS:  0.7922879928784302 0.8393905729950949 0.5168505712794828
# Conversion done !

# %%
# 22 06 22
ttfu = importlib.reload(ttfu)
file_name = "./data/calibration/lab_calib/20220622_calibration_warthog.csv"
file_name_output = "./data/calibration/distance_calib/20220622_calibration_distance.csv"
P1, P2, P3, G1, G2, G3, L = ttfu.read_calibration_gps_prism_lidar(file_name, file_name_output)
# Out:
# Distance inter-prism:  0.7359204697527427 0.9055056357941131 1.0268390664025775
# Distance inter-GPS:  0.7818105926683322 0.8536205673813737 0.5068640574720596
# Conversion done !

# %%
# 30 06 22
ttfu = importlib.reload(ttfu)
file_name = "./data/calibration/lab_calib/20220630_calibration_warthog.csv"
file_name_output = "./data/calibration/distance_calib/20220630_calibration_distance.csv"
P1, P2, P3, G1, G2, G3, L = ttfu.read_calibration_gps_prism_lidar(file_name, file_name_output)
# Out:
# Distance inter-prism:  0.7297583705742492 0.9060320633355149 1.0319114860615324
# Distance inter-GPS:  0.7844037235850999 0.8443517677165984 0.515075228247105
# Conversion done !

# %%
# 11 07 22
ttfu = importlib.reload(ttfu)
file_name = "./data/calibration/lab_calib/20220711_calibration_warthog.csv"
file_name_output = "./data/calibration/distance_calib/20220711_calibration_distance.csv"
P1, P2, P3, G1, G2, G3, L = ttfu.read_calibration_gps_prism_lidar(file_name, file_name_output)
# Out:
# Distance inter-prism:  0.7290056530579362 0.906995998154099 1.029264651249632
# Distance inter-GPS:  0.7825177240721779 0.8446820009426457 0.5145776023584968
# Conversion done !

# %%
# 17 07 22
ttfu = importlib.reload(ttfu)
file_name = "./data/calibration/lab_calib/20220717_calibration_marmotte.csv"
file_name_output = "./data/calibration/distance_calib/20220717_calibration_distance_marmotte.csv"
V1, V2, V3, V4, G1, G2, A1, A2, A3, p1, p2, p3 = ttfu.read_calibration_prism_lidar_marmotte(file_name, file_name_output)
# Out:
# [[-0.88826007  0.4401869  -0.13126138  1.83168429]
#  [-0.45544136 -0.88115053  0.12707048  1.20979242]
#  [-0.05972627  0.1726535   0.98317015  1.10050736]
#  [ 0.          0.          0.          1.        ]]
# [-0.38571473 -0.03856647  0.38253961  1.        ]
# [-0.64792705 -0.10196229  0.10085183  1.        ]
# [-0.6429175   0.15653089  0.07587566  1.        ]
# Distance inter-prism:  0.39002864329744197 0.4452628757931205 0.2597453130254009
# Conversion done !

# %%
# %matplotlib notebook
fig = plt.figure(figsize = (8, 6))
ax = plt.axes(projection ="3d")
#ax.scatter3D(V1[0],V1[1],V1[2], color='black')
#ax.scatter3D(V2[0],V2[1],V2[2], color='red')
#ax.scatter3D(V3[0],V3[1],V3[2], color='red')
#ax.scatter3D(V4[0],V4[1],V4[2], color='red')
#ax.scatter3D(G1[0],G1[1],G1[2], color='blue')
#ax.scatter3D(G2[0],G2[1],G2[2], color='green')
ax.scatter3D(0,0,0, color='orange')
ax.scatter3D(-0.85945263,2.07493247,1.09340118, color='blue')
ax.scatter3D(p1[0],p1[1],p1[2], color='green')
ax.scatter3D(p2[0],p2[1],p2[2], color='green')
ax.scatter3D(p3[0],p3[1],p3[2], color='green')
#ax.scatter3D(A1[0],A1[1],A1[2], color='blue')
#ax.scatter3D(A2[0],A2[1],A2[2], color='blue')
#ax.scatter3D(A3[0],A3[1],A3[2], color='blue')
ax.set_xlabel("X")
ax.set_ylabel("Y")
fig.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="799.5333333333333">

# %%
# %matplotlib notebook
fig = plt.figure(figsize = (8, 6))
ax = plt.axes()
ax.scatter(P1[0],P1[1], color='black')
ax.scatter(P2[0],P2[1], color='red')
ax.scatter(P3[0],P3[1], color='red')
ax.scatter(G1[0],G1[1], color='red')
ax.scatter(G2[0],G2[1], color='green')
ax.scatter(G3[0],G3[1], color='blue')
ax.scatter(p1[0],p1[1], color='green')
ax.scatter(p2[0],p2[1], color='green')
ax.scatter(p3[0],p3[1], color='green')
ax.set_xlabel("X")
ax.set_ylabel("Y")
fig.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="799.5333333333333">
